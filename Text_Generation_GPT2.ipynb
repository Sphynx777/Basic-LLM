# %% [markdown]
# <a href="https://colab.research.google.com/github/Sphynx777/Basic-LLM/blob/main/Text_Generation_GPT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = TFGPT2LMHeadModel.from_pretrained('gpt2')
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2LMHeadModel.
#
# All the weights of TFGPT2LMHeadModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.

# %%
text = "What is Generative AI?"
encoded_input = tokenizer.encode(text, return_tensors='pt')

# %%
tokenizer.decode(encoded_input[0][4])
# Out:
# ' AI'

# %%
output = model.generate(encoded_input, max_length=100, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)
# setting ' pad_token_id ' to 'eos_token_id': 50256 for open-end generation
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
output
# Out:
# <tf.Tensor: shape=(1, 100), dtype=int32, numpy=
# array([[ 2061,   318,  2980,   876,  9552,    30,   198,   198,  8645,
#           876, 35941,  9345,   357,    38, 20185,     8,   318,   257,
#           649,  2214,   286,  2267,   326, 12932,   284,  1833,   703,
#           262,  1692,  3632,  2499,   290,   703,   340, 44020,   351,
#           584,  3354,   286,   262,  3632,    13,   383,  3061,   286,
#           402, 20185,   318,   284,  2251,   257,  4572,   326,   318,
#          1498,   284,  1620,  8861,   326,   389,   407,  1744,   287,
#           262,  1103,   995,    11,   884,   355,  3555,    11,  3597,
#            11,   393,  2712,  2008,  1830,    13,   770,  4572,   318,
#          6007,   286,  9489,   867,   286,   777,  8861,   379,   262,
#           976,   640,    11,  1231,   262,   761,   329,  1692,  9572,
#            13]], dtype=int32)>

# %%
tokenizer.decode(output[0], skip_special_token=True)
# Out:
# 'What is Generative AI?\n\nGenerative Artificial Intelligence (GAI) is a new field of research that seeks to understand how the human brain works and how it interacts with other parts of the brain. The goal of GAI is to create a machine that is able to perform tasks that are not possible in the real world, such as reading, writing, or playing video games. This machine is capable of performing many of these tasks at the same time, without the need for human intervention.'
